# %%
import json
import requests
#api_key_angela = "AIzaSyC6nZNP58pIteBnFnejU7SeE0JnxA-gX2"
#api_key_jordina = "AIzaSyCDgZyP_DMLUmtg4KF9YEOCtneOeSSzYYs"
api_key_alba= "AIzaSyBC0KL7K-aWvcVfl4P4Ck_is4BZ8TdzSZI"
url = "https://www.googleapis.com/qpxExpress/v1/trips/search?key=" + api_key_alba
headers = {'content-type': 'application/json'}

params = {
  "request": {
    "slice": [
      {
        "origin": "BCN",
        "destination": "STN",
        "date": "2016-06-26"
                
      }
    ],
    "passengers": {
      "adultCount": 1
    },
    "flight": {
        "number": "VY_7964"
    },
    "solutions": 2,
    "refundable": False
  }
}

response = requests.post(url, data=json.dumps(params), headers=headers)
data = response.json()

# %%
#print data.get("kind")
#print response.text
#print data.values()
#print data["slice"]
#print data.get("trips")
#print data.trips
type(data)
# Out:
# dict

# %%
data
# Out:
# {u'kind': u'qpxExpress#tripsSearch',
#  u'trips': {u'data': {u'aircraft': [{u'code': u'321',
#      u'kind': u'qpxexpress#aircraftData',
#      u'name': u'Airbus A321'},
#     {u'code': u'32A',
#      u'kind': u'qpxexpress#aircraftData',
#      u'name': u'Airbus A320'},
#     {u'code': u'738',
#      u'kind': u'qpxexpress#aircraftData',
#      u'name': u'Boeing 737'}],
#    u'airport': [{u'city': u'BCN',
#      u'code': u'BCN',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'Barcelona'},
#     {u'city': u'IST',
#      u'code': u'SAW',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'Istanbul Sabiha Gokcen'},
#     {u'city': u'LON',
#      u'code': u'STN',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'London Stansted'},
#     {u'city': u'VIE',
#      u'code': u'VIE',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'Vienna International'}],
#    u'carrier': [{u'code': u'OS',
#      u'kind': u'qpxexpress#carrierData',
# ...

# %%
data.values()
# Out:
# [u'qpxExpress#tripsSearch',
#  {u'data': {u'aircraft': [{u'code': u'321',
#      u'kind': u'qpxexpress#aircraftData',
#      u'name': u'Airbus A321'},
#     {u'code': u'32A',
#      u'kind': u'qpxexpress#aircraftData',
#      u'name': u'Airbus A320'},
#     {u'code': u'738',
#      u'kind': u'qpxexpress#aircraftData',
#      u'name': u'Boeing 737'}],
#    u'airport': [{u'city': u'BCN',
#      u'code': u'BCN',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'Barcelona'},
#     {u'city': u'IST',
#      u'code': u'SAW',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'Istanbul Sabiha Gokcen'},
#     {u'city': u'LON',
#      u'code': u'STN',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'London Stansted'},
#     {u'city': u'VIE',
#      u'code': u'VIE',
#      u'kind': u'qpxexpress#airportData',
#      u'name': u'Vienna International'}],
#    u'carrier': [{u'code': u'OS',
#      u'kind': u'qpxexpress#carrierData',
#      u'name': u'Austrian'},
# ...

# %%
data["trips"]["data"].values()
# Out:
# [[{u'code': u'BCN', u'kind': u'qpxexpress#cityData', u'name': u'Barcelona'},
#   {u'code': u'IST', u'kind': u'qpxexpress#cityData', u'name': u'Istanbul'},
#   {u'code': u'LON', u'kind': u'qpxexpress#cityData', u'name': u'London'},
#   {u'code': u'VIE', u'kind': u'qpxexpress#cityData', u'name': u'Vienna'}],
#  u'qpxexpress#data',
#  [{u'id': u'AT_001',
#    u'kind': u'qpxexpress#taxData',
#    u'name': u'Austria Passenger Security Charge'},
#   {u'id': u'TR_001',
#    u'kind': u'qpxexpress#taxData',
#    u'name': u'Turkey Airport Service Charge International'},
#   {u'id': u'YQ_F',
#    u'kind': u'qpxexpress#taxData',
#    u'name': u'PC YQ surcharge'},
#   {u'id': u'QV_001',
#    u'kind': u'qpxexpress#taxData',
#    u'name': u'Spain Security Tax'},
#   {u'id': u'ZY_001',
#    u'kind': u'qpxexpress#taxData',
#    u'name': u'Austria Passenger Service Charge'},
#   {u'id': u'OG_001',
#    u'kind': u'qpxexpress#taxData',
#    u'name': u'Spain Aviation Safety And Security Fee'},
# ...

# %%
file=open("out.xls", "w")
file.write(response.content)

# %%
data["trips"]["tripOption"][1]["pricing"][0]
# Out:
# {u'baseFareTotal': u'EUR229.00',
#  u'fare': [{u'basisCode': u'W10CLS0D',
#    u'carrier': u'OS',
#    u'destination': u'VIE',
#    u'id': u'Alxq34n6I1Ib4RqM4tbyx3YdLgQwGWR+STPS8uWMGThc',
#    u'kind': u'qpxexpress#fareInfo',
#    u'origin': u'BCN'},
#   {u'basisCode': u'W10CLS0D',
#    u'carrier': u'OS',
#    u'destination': u'LON',
#    u'id': u'A/5HV3nngzo9iXeMHlJqF2kTS42VO/HOfTImikMdlnYg',
#    u'kind': u'qpxexpress#fareInfo',
#    u'origin': u'VIE'}],
#  u'fareCalculation': u'BCN OS X/VIE 133.58W10CLS0D OS LON 116.61W10CLS0D NUC 250.19 END ROE 0.913258 FARE EUR 229.00 XT 15.03JD 0.59OG 3.71QV 8.37AT 18.43ZY 42.00YQ 16.00YR',
#  u'kind': u'qpxexpress#pricingInfo',
#  u'latestTicketingTime': u'2016-06-13T18:35-04:00',
#  u'passengers': {u'adultCount': 1, u'kind': u'qpxexpress#passengerCounts'},
#  u'ptc': u'ADT',
#  u'saleFareTotal': u'EUR229.00',
#  u'saleTaxTotal': u'EUR104.13',
#  u'saleTotal': u'EUR333.13',
# ...

# %%
type (data["trips"]["tripOption"][1])
# Out:
# dict

# %%
type(data["trips"]["tripOption"][1]["pricing"])
# Out:
# list
