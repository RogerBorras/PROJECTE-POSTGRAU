# %%
import pandas as pd
import pylab as pl
import numpy as np

# %%
vols = pd.read_csv('C:/Users/usuario/Desktop/POSTGRAU_DATA_SCIENCE/PROJECTE_POSTGRAU/RECOMANADOR/dades_4_07_2016.csv')

# %%
vols
# Out:
#        Unnamed: 0 ID_Vuelo  Id_bitllet   dia_query dia_query_dia_setmana  \
# 0              73   BA2046          20  2015-11-17               dimarts
# 1             152   BA2046          20  2015-11-18              dimecres
# 2             404   BA2046          20  2015-11-22              diumenge
# 3             754   BA2046          20  2015-11-27             divendres
# 4            1104   BA2046          20  2015-12-02              dimecres
# 5            1449   BA2046          20  2015-12-07               dilluns
# 6            1784   BA2046          20  2015-12-12              dissabte
# 7             480   BA2046          21  2015-11-23               dilluns
# 8             830   BA2046          21  2015-11-28              dissabte
# 9            1174   BA2046          21  2015-12-03                dijous
# 10           1524   BA2046          21  2015-12-08               dimarts
# 11           1855   BA2046          21  2015-12-13              diumenge
# ...

# %%
list(vols.columns.values)
# Out:
# ['Unnamed: 0',
#  'ID_Vuelo',
#  'Id_bitllet',
#  'dia_query',
#  'dia_query_dia_setmana',
#  'dias_antelacion',
#  'aerolinia',
#  'nombre_ciudad_origen',
#  'nombre_ciudad_destino',
#  'precio',
#  'fecha_salida',
#  'fecha_salida_dia_setmana',
#  'hora_salida',
#  'fecha_llegada',
#  'fecha_llegada_dia_setmana',
#  'hora_llegada',
#  'duracion',
#  'demanda',
#  'baixada_preu']

# %%
print vols.head()
# Out:
#   File "<ipython-input-6-116709645afd>", line 1
#     print vols.head()
#              ^
# SyntaxError: invalid syntax

# %%
print vols.describe()
# Out:
#   File "<ipython-input-7-62524ff77005>", line 1
#     print vols.describe()
#              ^
# SyntaxError: invalid syntax

# %%
from sklearn import preprocessing
['Unnamed: 0',
 'ID_Vuelo',
 'Id_bitllet',
 'dia_query',
 'dia_query_dia_setmana',
 'dias_antelacion',
 'aerolinia',
 'nombre_ciudad_origen',
 'nombre_ciudad_destino',
 'precio',
 'fecha_salida',
 'fecha_salida_dia_setmana',
 'hora_salida',
 'fecha_llegada',
 'fecha_llegada_dia_setmana',
 'hora_llegada',
 'duracion',
 'demanda',
 'baixada_preu']

X = vols[["aerolinia","dia_query","precio","dias_antelacion", "nombre_ciudad_destino",
          "nombre_ciudad_destino", "fecha_salida_dia_setmana", "demanda"]]
Y = vols[["baixada_preu"]]
X = pd.get_dummies(vols[["precio","dias_antelacion", "nombre_ciudad_destino", "fecha_salida_dia_setmana", "demanda"]])
X
# Out:
#        precio  dias_antelacion  demanda  nombre_ciudad_destino_Birmingham  \
# 0       77.69              -35        0                                 0
# 1       77.69              -34        0                                 0
# 2       77.69              -30        0                                 0
# 3       77.69              -25        0                                 0
# 4       77.69              -20        0                                 0
# 5       77.69              -15        0                                 0
# 6       77.69              -10        0                                 0
# 7       77.69              -30        0                                 0
# 8       77.69              -25        0                                 0
# 9       77.69              -20        0                                 0
# 10      77.69              -15        0                                 0
# 11      77.69              -10        0                                 0
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 150)
forest = forest.fit(X, Y)
predictions = forest.predict(X)
accuracy_score(Y, predictions)
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()
# 0.92256901133467106

# %%
vols["dias_antelacion", "nombre_ciudad_destino", "fecha_salida_dia_setmana", "demanda"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-dc043df4eeda> in <module>()
# ----> 1 vols["dias_antelacion", "nombre_ciudad_destino", "fecha_salida_dia_setmana", "demanda"]
#
# /home/roger/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /home/roger/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# ...
